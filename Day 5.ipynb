# %%
def count_even_numbers(*i):
    even_count = 0
    for n in i:
        if n % 2 == 0:
            even_count += 1
    return even_count    

count_even_numbers(3,4,6,8,9)

# %%
numbers = [1,2,3,4,5,6,7,8]

square_numbers = []

for i in numbers:
    if i %2 == 0:
        square_numbers.append(i*i)
print(square_numbers)
# Out:
# [4, 16, 36, 64]

# %%
def greet_user(username):
    print(f"Hello, {username} !")

# %%
greet_user("Sanjay")
# Out:
# Hello, Sanjay !

# %%
def addition(numbers):
    numbers = int(numbers)
    return(sum(numbers))

# %%
def addition(first_number, second_number):
    total = first_number + second_number
    return total

addition(10,20)
# Out:
# 30

# %%
def add(*additional_numbers):
    for i in additional_numbers:
        total = i + i
    return total

# %%
def square_numbers(i):
    return i*i
square_numbers(6)
# Out:
# 36

# %%
def even_numbers(i):
    if i %2 == 0:
        print(f"the input number {i} is even")
    else:
        print(f"the input number {i} is odd")

# %%
def is_positive(i):
    if i > 0:
        print("positive")
    elif i < 0: 
        print("Negative") 
    else:
        print("Zero")   

classify_number(-3)
# Out:
# 'Negative'

# %%
def is_negative(i):
    return i < 0
print(is_negative(-3))
# Out:
# True

# %%
def calculate_total(*numbers):
    total = 0
    for i in numbers:
        total += i
    return total

calculate_total(10,20,30,90)
# Out:
# 150

# %%
def classify_number(i):
    if i > 0:
        return "positive"
    elif i < 0: 
        return "Negative" 
    else:
        return "Zero"   

classify_number(3)
# Out:
# 'positive'

# %%
def find_largest(*numbers):
    largest = 0

    for number in numbers:
        if number > largest:
            largest = number
    return(largest)

# %%
find_largest(3,99,8,9)
# Out:
# 99

# %%
def count_even_numbers(*numbers):
    even_count = 0

    for i in numbers:
        if i %2 == 0:
            even_count +=1
    
    return even_count    

count_even_numbers(3,4,6,8,9)
# Out:
# 3

# %%
count_even_numbers(2, 5, 8, 11, 14)
# Out:
# 3

# %%
def calculate_average(*numbers):
    total = 0
    for i in numbers:
        total += i
    avg = total/len(numbers)
    return avg

calculate_average(10, 20, 30)
# Out:
# 20.0

# %%
calculate_average(10, 20, 30)
# Out:
# 20.0

# %%
def calculate_average(*numbers):
    total = 0
    for i in numbers:
        total += i
    avg = total/len(numbers)
    return avg

calculate_average(10, 40, 10)
# Out:
# 20.0

# %%
calculate_average(10, 0, 30)
# Out:
# 10
