# %% [markdown]
# ## Day 2

# %%
user_age = int(input("Enter your age:"))

if user_age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %%
## 2

user_marks = int(input("Enter your marks:"))

if 90 <= user_marks <= 100:
    print("Grade A")
elif 75 <= user_marks <= 89:
    print("Grade B")   
elif 60 <= user_marks <= 74:
    print("Grade C")
elif 40 <= user_marks <= 59:
    print("Grade D")
else:
    user_marks <= 40
    print("Fail")
# Out:
# Fail

# %%
user_input = int(input("Enter any number:"))

if user_input > 0:
    print("positive")
elif user_input < 0:
    print("negative")  
else:
    user_input = 0,
    print("Zero")
# Out:
# negative

# %%
input_1 = int(input("Enter first number :"))
input_2 = int(input("Enter first number :"))

inputs = [input_1,input_2]

if input_1 > input_2 or input_2 >input_1:
    greater_number = max(inputs)
    print("the greater number is ", greater_number)
else:
    print("both numbers are equal")
# Out:
# the greater number is  54

# %%
input_number = int(input("Enter first number :"))

if input_number %2 == 0:
    print(f"the entered number {input_number} is even")
else:
    print(f"the entered number {input_number} is odd")
# Out:
# the entered number 5 is odd

# %%
user_age = int(input("Enter your age :"))

if user_age < 13:
    print("the user is Chlid")
elif 13 <= user_age <= 19 :
    print("the user is Teenager")  
elif 20 <= user_age <= 59 :
    print("the user is Adult") 
else:
    user_age > 60,
    print("the user is Senior")
# Out:
# the user is Chlid
