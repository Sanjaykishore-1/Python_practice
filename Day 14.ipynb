# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93},
    "Noah": {"Math": 84, "Science": 87, "English": 82},
    "Ava": {"Math": 91, "Science": 94, "English": 90}
}


for student, subjects in students.items():
#    for subject, marks in subjects.items():
    total = sum(subjects.values())
    avg = round(total/len(subjects),2)

    if avg > 90:
        print(f"The student {student} of total : {total} in average: {avg} is Excellent")

    elif 80 <= avg: #or avg > 89.99:
            print(f"The student {student} of total : {total} in average: {avg} is Good")
                
    else:
            print(f"The student {student} of total : {total} in average: {avg} is Needs Improvement")
# Out:
# The student Maya of total : 265 in average: 88.33 is Good
# The student Liam of total : 236 in average: 78.67 is Needs Improvement
# The student Sofia of total : 277 in average: 92.33 is Excellent
# The student Noah of total : 253 in average: 84.33 is Good
# The student Ava of total : 275 in average: 91.67 is Excellent

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93},
    "Noah": {"Math": 84, "Science": 87, "English": 82},
    "Ava": {"Math": 91, "Science": 94, "English": 90}
}

excellent_count = 0
good_count = 0
needs_improvement_count = 0

for student, subjects in students.items():
#    for subject, marks in subjects.items():
    total = sum(subjects.values())
    avg = round(total/len(subjects),2)

    if avg >= 90:
        excellent_count += 1
        
        print(f"The student {student} of total : {total} in average: {avg} is Excellent")

    elif 80 <= avg: #or avg > 89.99:
            good_count += 1
            print(f"The student {student} of total : {total} in average: {avg} is Good")
                
    else:
            needs_improvement_count += 1
            print(f"The student {student} of total : {total} in average: {avg} is Needs Improvement") 

print("Excellent_count :", excellent_count)
print("Good_count :",good_count)
print("Needs_improvement_count :",needs_improvement_count)
# Out:
# The student Maya of total : 265 in average: 88.33 is Good
# The student Liam of total : 236 in average: 78.67 is Needs Improvement
# The student Sofia of total : 277 in average: 92.33 is Excellent
# The student Noah of total : 253 in average: 84.33 is Good
# The student Ava of total : 275 in average: 91.67 is Excellent
# Excellent_count : 2
# Good_count : 2
# Needs_improvement_count : 1

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93},
    "Noah": {"Math": 84, "Science": 87, "English": 82},
    "Ava": {"Math": 91, "Science": 94, "English": 90}
}

excellent_students = []
good_students = []
needs_improvement_students = []

for student, subjects in students.items():
    total = sum(subjects.values())
    avg = round(total/len(subjects),2)

    if avg >= 90:
        print(f"The student {student} of total : {total} in average: {avg} is Excellent")
        excellent_students.append(student)

    elif 80 <= avg: #or avg > 89.99:
        print(f"The student {student} of total : {total} in average: {avg} is Good")
        good_students.append(student)    
    else:
        print(f"The student {student} of total : {total} in average: {avg} is Needs Improvement") 
        needs_improvement_students.append(student)

print("\nExcellent_students :", excellent_students)

print("Good_students :",good_students)

print("\nNeeds_improvement_students :",needs_improvement_students)
# Out:
# The student Maya of total : 265 in average: 88.33 is Good
# The student Liam of total : 236 in average: 78.67 is Needs Improvement
# The student Sofia of total : 277 in average: 92.33 is Excellent
# The student Noah of total : 253 in average: 84.33 is Good
# The student Ava of total : 275 in average: 91.67 is Excellent
#
# Excellent_students : ['Sofia', 'Ava']
# Good_students : ['Maya', 'Noah']
#
# Needs_improvement_students : ['Liam']

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93},
    "Noah": {"Math": 84, "Science": 87, "English": 82},
    "Ava": {"Math": 91, "Science": 94, "English": 90}
}

excellent_students = []
good_students = []
needs_improvement_students = []

for student, subjects in students.items():
    total = sum(subjects.values())
    avg = round(total/len(subjects),2)

    if avg >= 90:
        print(f"The student {student} of total : {total} in average: {avg} is Excellent")
        excellent_students.append(student)

    elif 80 <= avg: #or avg > 89.99:
        print(f"The student {student} of total : {total} in average: {avg} is Good")
        good_students.append(student)    
    else:
        print(f"The student {student} of total : {total} in average: {avg} is Needs Improvement") 
        needs_improvement_students.append(student)

print("\nExcellent_students:")
for i, student in enumerate(excellent_students, start=1):
    print(f"{i}. {student}")

print("\nGood_students:")
for i, student in enumerate(good_students, start=1):
    print(f"{i}. {student}")

print("\nNeeds_improvement_students:")
for i, student in enumerate(needs_improvement_students, start=1):
    print(f"{i}. {student}")
# Out:
# The student Maya of total : 265 in average: 88.33 is Good
# The student Liam of total : 236 in average: 78.67 is Needs Improvement
# The student Sofia of total : 277 in average: 92.33 is Excellent
# The student Noah of total : 253 in average: 84.33 is Good
# The student Ava of total : 275 in average: 91.67 is Excellent
#
# Excellent_students:
# 1. Sofia
# 2. Ava
#
# Good_students:
# 1. Maya
# 2. Noah
#
# Needs_improvement_students:
# 1. Liam

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93},
    "Noah": {"Math": 84, "Science": 87, "English": 82},
    "Ava": {"Math": 91, "Science": 94, "English": 90}
}

user_input = input("Enter the subject :" ).strip().lower()
Math_student_count = 0
science_student_count = 0
English_student_count = 0

for student, subjects in students.items():
#    for subject in subjects.items():
        if user_input == "math":
            Math_student_count += 1
            print("the math students are ", student)
        elif user_input == "science":
            science_student_count += 1
            print("the science students are ", student)
        elif user_input == "english":
            science_student_count += 1
            print("the english students are ", student) 
        else:
            print("Illvalid input please give valid subject details")
        
print("Math students counts: ",Math_student_count)
print("science students counts: ",science_student_count)
print("English students counts: ",English_student_count)
# Out:
# the science students are  Maya
# the science students are  Liam
# the science students are  Sofia
# the science students are  Noah
# the science students are  Ava
# Math students counts:  0
# science students counts:  5
# English students counts:  0

# %%
user_input = input("Enter the subject: ").strip().lower()

valid_subjects = ("math", "science", "english")

if user_input not in valid_subjects:
    print("Invalid input. Please enter Math, Science, or English.")
else:
    subject_name = user_input.title()
    matching_students = []

    for student, subjects in students.items():
        if subject_name in subjects:
            matching_students.append(student)
            print(f"{student} has {subject_name}.")

    print(f"{subject_name} student count:", len(matching_students))
# Out:
# Maya has Math.
# Liam has Math.
# Sofia has Math.
# Noah has Math.
# Ava has Math.
# Math student count: 5
