# %%
def count_long_words(sentence):
    word_count = 0
    words = sentence.split()
    
    for word in words:
        if len(word) > 5:
            word_count += 1
    
    return word_count

    print(sentence)
    print("long count words are: ", word_count)

# %%
count_long_words("Python programming is interesting yaarrr")
# Out:
# 4

# %%
student = { "Name": "sanjay",
                    "Age" : "24",
                    "course": "python"
}

print(student)
print(student["Name"])
print(student["Age"])

student["Is_learning"] = True

print(student)
# Out:
# {'Name': 'sanjay', 'Age': '24', 'course': 'python'}
# sanjay
# 24
# {'Name': 'sanjay', 'Age': '24', 'course': 'python', 'Is_learning': True}

# %%
student = { "Name": "sanjay",
                    "Age" : "24",
                    "course": "python"
}

student["Is_learning"] = True

for key, value in student.items():
    print(key, ":", value)
# Out:
# Name : sanjay
# Age : 24
# course : python
# Is_learning : True

# %%
student = { "Name": "sanjay",
                    "Age" : "24",
                    "course": "python"
}

student["Is_learning"] = True
student["Age"] = 25
student["course"] = "Deep Learning"
student["city"] = "Chennai"

for key, value in student.items():
    print(key, ":", value)
# Out:
# Name : sanjay
# Age : 25
# course : Deep Learning
# Is_learning : True
# city : Chennai

# %%
employee = { "Name": "sanjay",
            "role" : "data scientist",
            "dept": "data & ai"}

print(employee["Name"])
print(employee.get("role"))
print(employee.get("Location"))
# Out:
# sanjay
# data scientist
# None

# %%
employee = {
    "name": "Sanjay",
    "role": "Data Scientist",
    "department": "Data & AI"
}

location = employee.get("location", "Location not provided")
print(location)
# Out:
# Location not provided

# %%
product = {
    "name" : "Coffee mug",
    "price": 230 ,
    "category": "Home appliances"
}

stock = product.get("stock", "Stock information unavailable")
print(stock)
# Out:
# Stock information unavailable

# %%
cart = { "book": 250,
        "pen": 50,
        "bag": 800 }

Total = 0

for i in cart:
    Total = sum(cart.values())

print(Total)
# Out:
# 1100

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93}
}

highest_score = 0
for subject, score in marks.items():
    if score > highest_score:
        highest_score = score

print("Highest score:", highest_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 8
#       4     "Sofia": {"Math": 95, "Science": 89, "English": 93}
#       5 }
#       6
#       7 highest_score = 0
# ----> 8 for subject, score in marks.items():
#       9     if score > highest_score:
#      10         highest_score = score
#      11
#
# NameError: name 'marks' is not defined

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93}}

high_scores = 0

for n in students.values():
    for score in n.values():
        if score > high_scores:
            high_scores = score

print(high_scores)
# Out:
# 95

# %%
students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93}}

for name,mark in students.items():
    total = 0

    for marks in mark.values():
        total += marks

    avg   = total/len(mark)
    
    print(name, avg )
# Out:
# Maya 88.33333333333333
# Liam 78.66666666666667
# Sofia 92.33333333333333

# %%
# filename: student-averages.py
# Code Generated by Sidekick is for learning and experimentation purposes only.

students = {
    "Maya": {"Math": 88, "Science": 92, "English": 85},
    "Liam": {"Math": 76, "Science": 81, "English": 79},
    "Sofia": {"Math": 95, "Science": 89, "English": 93}
}

for name, subjects in students.items():
    total = 0

    for score in subjects.values():
        total += score

    average = total / len(subjects)

    print(name, "average:", average)
# Out:
# Maya average: 88.33333333333333
# Liam average: 78.66666666666667
# Sofia average: 92.33333333333333
